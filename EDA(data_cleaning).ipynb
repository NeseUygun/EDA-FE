# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("googleplaystore.csv")

# %%
df = data.copy()

# %%
#First 5 rows
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Last five rows
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
#If you do not determine how many samples do you want to get, it gives you one sample.
df.sample()
# Out:
#                                   App            Category  Rating Reviews  \
# 10336  Santa Fe New Mexican e-Edition  NEWS_AND_MAGAZINES     4.1      25
#
#       Size Installs  Type Price Content Rating            Genres  \
# 10336  17M   1,000+  Free     0       Everyone  News & Magazines
#
#         Last Updated    Current Ver Android Ver
# 10336  June 21, 2018  4.7.4.18.0621  4.1 and up

# %%
data.sample(20)
# Out:
#                                                      App            Category  \
# 6447                                    BL Kennedy Theme     PERSONALIZATION
# 6768                          BT One Voice mobile access       COMMUNICATION
# 5759                            Square Analog Clock AW-7               TOOLS
# 8516                           Download Manager Pro FREE        PRODUCTIVITY
# 8422                                             DH News  NEWS_AND_MAGAZINES
# 9561                                          Fernanfloo                GAME
# 6175                                             trip.bg    TRAVEL_AND_LOCAL
# 332                                         think Comics              COMICS
# 4149                                       Offroad Car G              FAMILY
# 4486                     Android P Launcher 9.0 launcher               TOOLS
# 4415                         Cook 'n Learn Smart Kitchen              FAMILY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe(include="all").T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %%
data[data.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#It is object type but it should be converted numeric (int)
df["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
df.Reviews.str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10841, dtype: bool

# %%
df.Reviews.str.isnumeric().value_counts()
# Out:
# True     10840
# False        1
# Name: Reviews, dtype: int64

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Let's drop this row that is not numeric
df = df.drop(df.index[10472])

# %%
#check it is removed or not
df[~df.Reviews.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.shape
# Out:
# (10840, 13)

# %%
data.shape
# Out:
# (10841, 13)

# %%
df["Reviews"] = df["Reviews"].astype("int")

# %%
df["Reviews"].dtype
# Out:
# dtype('int64')

# %%
df["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
df["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# dtype of Size is object but it should be float and there is 'Varies with device' text in some rows so we need to remove it
# or make nan value. Number of it is high so I will replace it with nan.
df["Size"].str.contains('Varies with device').value_counts()
# Out:
# False    9145
# True     1695
# Name: Size, dtype: int64

# %%
df["Size"] = df["Size"].str.replace('Varies with device', str(np.nan))

# %%
#convert M to kb then handle dtype of this feature.
df["Size"] = df["Size"].str.replace("M", "000")

# %%
df["Size"] = df["Size"].str.replace("k", "")

# %%
df["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df["Size"] = df["Size"].astype("float")

# %%
df["Size"].dtype
# Out:
# dtype('float64')

# %%
df["Size"]
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
print(data["Size"][0])
print(data["Size"][2])
# Out:
# 19M
# 8.7M

# %%
df["Size"].head()
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# 4        2.8
# Name: Size, dtype: float64

# %%
df.Size[df["Size"] < 100].unique()
# Out:
# array([ 8.7,  2.8,  5.6,  3.1,  2.7,  5.5,  4.2,  7. ,  6. ,  6.1,  4.6,
#         9.2,  5.2,  9.4,  1.2,  8. ,  7.9,  3.6,  5.7,  8.6,  2.4,  2.5,
#         3.4,  8.9,  3.9,  2.9,  5.4,  1.1,  2.2,  4.5,  9.8,  9. ,  6.7,
#         2.6,  7.1,  3.7,  7.4,  6.4,  3.2,  8.2,  9.9,  4.9,  9.5,  5. ,
#         5.9,  6.8,  3.5,  4. ,  2.3,  7.2,  2.1,  7.3,  9.1, 23. ,  6.5,
#         1.5,  7.5,  8.5,  8.3,  4.3,  4.7,  3.3,  7.8,  8.8,  6.6,  5.1,
#        79. ,  8.4,  1.6,  6.2, 18. ,  1.4,  3. ,  5.8,  3.8,  9.6,  4.4,
#         4.8,  6.9,  9.3, 10. ,  8.1,  2. ,  1.9,  1.8,  5.3,  7.6,  9.7,
#         7.7,  6.3, 41. , 11. ,  1.7,  1.3,  4.1, 58. , 51. , 26. , 91. ,
#        17. , 74. , 14. , 78. , 81. , 45. , 61. , 93. ,  1. , 70. , 55. ,
#        25. , 27. , 82. , 29. , 50. , 97. , 20. , 72. , 33. , 34. , 28. ,
#        54. , 48. , 24. , 39. , 73. , 89. , 44. , 67. ])

# %%
for i in df["Size"]:
    if i < 10:
        df["Size"]= df["Size"].replace(i,i*1000)

# %%
df["Size"]
# Out:
# 0        19000.0
# 1        14000.0
# 2         8700.0
# 3        25000.0
# 4         2800.0
#           ...
# 10836    53000.0
# 10837     3600.0
# 10838     9500.0
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df["Size"] = df["Size"]/1000

# %%
df["Size"]
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10840, dtype: float64

# %%
df["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
df["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
char_to_removes = ["+", ",", "$"]
cols_to_clean = ["Installs","Price"]
for item in char_to_removes:
    for col in cols_to_clean:
        df[col] = df[col].str.replace(item, "")
# Out:
# /var/folders/hq/f4fnfxxj0psb8f_l4kc58_tr0000gn/T/ipykernel_1742/3013368708.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col] = df[col].str.replace(item, "")

# %%
df["Installs"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10840, dtype: object

# %%
df["Price"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10840, dtype: object

# %%
df["Installs"] = df["Installs"].astype("int")

# %%
df["Price"] = df["Price"].astype("float")

# %%
df["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
df["Last Updated"] = pd.to_datetime(df["Last Updated"])

# %%
df["Last Updated"]
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
df["Day"] = df["Last Updated"] .dt.day

# %%
df["Day"]
# Out:
# 0         7
# 1        15
# 2         1
# 3         8
# 4        20
#          ..
# 10836    25
# 10837     6
# 10838    20
# 10839    19
# 10840    25
# Name: Day, Length: 10840, dtype: int64

# %%
df["Month"] = df["Last Updated"] .dt.month

# %%
df["Year"] = df["Last Updated"] .dt.year

# %%
df["Current Ver"] = df["Current Ver"].str.replace("Varies with device","NaN")

# %%
df["Current Ver"]
# Out:
# 0        1.0.0
# 1        2.0.0
# 2        1.2.4
# 3          NaN
# 4          1.1
#          ...
# 10836     1.48
# 10837      1.0
# 10838      1.0
# 10839      NaN
# 10840      NaN
# Name: Current Ver, Length: 10840, dtype: object

# %%
df["Android Ver"]=df["Android Ver"].str.replace("and up","")
df["Android Ver"]=df['Android Ver'].str.replace("Varies with device","NaN")

# %%
df["Android Ver"]
# Out:
# 0        4.0.3
# 1        4.0.3
# 2        4.0.3
# 3          4.2
# 4          4.4
#           ...
# 10836      4.1
# 10837      4.1
# 10838      2.2
# 10839       NaN
# 10840       NaN
# Name: Android Ver, Length: 10840, dtype: object

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  Day  Month  \
# 0               Art & Design   2018-01-07       1.0.0      4.0.3     7      1
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0      4.0.3    15      1
#
#    Year
# 0  2018
# 1  2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Year            10840 non-null  int64
# ...

# %%
df.to_csv("cleaned_google_playstore_data.csv",index=False)
